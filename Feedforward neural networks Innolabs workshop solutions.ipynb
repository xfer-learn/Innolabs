# %% [markdown]
# # Feedforward neural networks

# %% [markdown]
# In this notebook we will learn how to apply neural networks to classification problems. You have already seen how neural networks work, and how they are trained. The biggest difference between regression and classification applications is the choice of cost function.

# %% [markdown]
# ## 1 The MNIST dataset - the "Hello, world!" of neural network classification

# %% [markdown]
# ### 1.1 The dataset

# %% [markdown]
# The MNIST dataset is a well-known collection of handwritten digits used for machine learning and computer vision research. It consists of 70,000 grayscale images of handwritten digits, each of size 28x28 pixels. The digits are labeled with their corresponding numerical values, ranging from 0 to 9.
#
# The MNIST dataset has been widely used as a benchmark for evaluating the performance of various machine learning algorithms, particularly those that involve image recognition or classification. The dataset is often used to train and test algorithms for tasks such as digit recognition, character recognition, and image classification. The MNIST dataset has also played a key role in the development of deep learning algorithms, including convolutional neural networks (CNNs), which have achieved state-of-the-art performance on the task of recognizing handwritten digits.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# Load the data using the Keras datasets API and split it between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# %% [markdown]
# ### 1.2 Visualizing the dataset

# %%
x_train.shape # 60,000 training examples of size 28 pixels by 28 pixels
# Out:
# (60000, 28, 28)

# %%
y_train.shape # 60,000 labels
# Out:
# (60000,)

# %%
x_train[0].max()
# Out:
# 255

# %%
x_train[0].min()
# Out:
# 0

# %%
# Plot a random sample from the dataset
indices = np.random.choice(len(x_train), size=9, replace=False)

for count, value in enumerate(indices):
    plt.subplot(3, 3, count+1)
    plt.imshow(x_train[value], cmap="gray")
    plt.title(y_train[value])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.3 Building the network

# %% [markdown]
# When building the classifier notebook there are a few things to keep in mind:
# 1. The shape of the input data is 2 dimensional. A fully-connected neural network can only handle 1-dimensional data. So we need to "flatten" the data into 1 dimension.
# 2. The values of the pixels are between 0 and 255. A neural network is better at handling normalized data, with values between 0 and 1. So we have to rescale our input pixel values.
# 3. This is a classification problem with multiple possible labels. The correct loss function to use in this case is the "categorical cross entropy" loss.

# %%
# Import necessary libraries from keras
from tensorflow.keras import layers

# Build a model using the "Sequential" API
model = keras.Sequential([
      layers.Flatten(input_shape=(28, 28)), # Flatten 2D input to 1D input
      layers.Dense(128, activation='relu'), # First hidden layer with 128 neurons, ReLU activation
      layers.Dense(10, activation='softmax') # Final layer to predict the label, with 10 classes
  ])

# %% [markdown]
# This model will output 10 numbers. We need to convert these 10 numbers into probabilities, and then create a loss function on top of these probabilities that checks whether the true label has the highest probability. Both of these steps can be done with one loss function in Keras, which is the "sparse categorical crossentropy" loss function. The parameter "from_logits = True" ensures that ther output of the neural network is first converted into a log probability. (If we didn't do from_logits=True, we would first have to apply a softmax activation layer on the output to convert the output to probabilities).

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001), # The Adam optimizer (an improvement over stochastic gradient descent)
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False), # Loss function for multi-class classification
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()], # Print the accuracy after each epoch
)

# %% [markdown]
# ### 1.4 Training the model

# %% [markdown]
# Now we feed the training features and labels to the model and train it for several epochs using backpropagation and the Adam optimizer.

# %%
history = model.fit(x_train, y_train, validation_split=0.1, epochs=10, batch_size=128, verbose=1)
# Out:
# Epoch 1/10
# 422/422 [==============================] - 3s 4ms/step - loss: 5.0477 - sparse_categorical_accuracy: 0.8556 - val_loss: 1.0364 - val_sparse_categorical_accuracy: 0.9083
# Epoch 2/10
# 422/422 [==============================] - 2s 4ms/step - loss: 0.7611 - sparse_categorical_accuracy: 0.9078 - val_loss: 0.6415 - val_sparse_categorical_accuracy: 0.9090
# Epoch 3/10
# 422/422 [==============================] - 2s 4ms/step - loss: 0.3876 - sparse_categorical_accuracy: 0.9281 - val_loss: 0.4287 - val_sparse_categorical_accuracy: 0.9325
# Epoch 4/10
# 422/422 [==============================] - 1s 3ms/step - loss: 0.2761 - sparse_categorical_accuracy: 0.9399 - val_loss: 0.3969 - val_sparse_categorical_accuracy: 0.9322
# Epoch 5/10
# 422/422 [==============================] - 1s 3ms/step - loss: 0.2125 - sparse_categorical_accuracy: 0.9508 - val_loss: 0.3135 - val_sparse_categorical_accuracy: 0.9445
# Epoch 6/10
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1625 - sparse_categorical_accuracy: 0.9583 - val_loss: 0.3209 - val_sparse_categorical_accuracy: 0.9473
# Epoch 7/10
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1494 - sparse_categorical_accuracy: 0.9617 - val_loss: 0.2887 - val_sparse_categorical_accuracy: 0.9527
# Epoch 8/10
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1430 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.3100 - val_sparse_categorical_accuracy: 0.9507
# Epoch 9/10
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1310 - sparse_categorical_accuracy: 0.9658 - val_loss: 0.2906 - val_sparse_categorical_accuracy: 0.9515
# Epoch 10/10
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1265 - sparse_categorical_accuracy: 0.9674 - val_loss: 0.2657 - val_sparse_categorical_accuracy: 0.9555

# %% [markdown]
# We can see the accuracy is over 95% at the end of the last epoch!

# %% [markdown]
# ### 1.5 Visualize the results

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], 'g', label='Validation loss')
plt.xlabel('Epoch #')
plt.ylabel('Loss (Categorical Cross-entropy)')
plt.title('Loss')
plt.legend()

# %%
# Evaluate model on test set

score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.3446328938007355
# Test accuracy: 0.9448999762535095

# %% [markdown]
# ## 5 Exercises

# %% [markdown]
# #### Question 1: Visit the website of the [TensorFlow Playground](https://playground.tensorflow.org/). Under "Problem type", select "Classification". On the left, select the fourth dataset, that looks like a spiral pattern. Make the "Ratio of training to test data:" 80%.
#
# #### Your task in this question is to play around with the number of hidden layers, number of neurons per hidden layer, learning rate, batch size, and activation functions, until you get a network that can make a good classification (low loss) on the training dataset.

# %% [markdown]
# #### Question 2: Once you have a model that works, implement it in this notebook in TensorFlow. The code below creates the dataset for you.

# %%
import random
import math
from typing import List

class Example2D:
    def __init__(self, x: float, y: float, label: int):
        self.x = x
        self.y = y
        self.label = label

def classifySpiralData(numSamples: int, noise: float) -> List[Example2D]:
    points = []
    n = int(numSamples / 2)

    def genSpiral(deltaT: float, label: int) -> None:
        for i in range(n):
            r = i / n * 5
            t = 1.75 * i / n * 2 * 3.14159 + deltaT
            x = r * math.sin(t) + random.uniform(-1, 1) * noise
            y = r * math.cos(t) + random.uniform(-1, 1) * noise
            points.append(Example2D(x, y, label))

    genSpiral(0, 1) # Positive examples.
    genSpiral(3.14159, 0) # Negative examples.
    return points


points = classifySpiralData(500, 0)

x1 = [p.x for p in points]
x2 = [p.y for p in points]
y = [p.label for p in points]

# This is your dataset
pointsdf = pd.DataFrame(data={'x1': x1, 'x2': x2})

# These are your labels
labelsdf = pd.Series(y)

pointsdf.plot.scatter('x1', 'x2', c=y)
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %%
# Split data into training and test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(pointsdf, labelsdf, test_size=0.1, random_state=42)

# %% [markdown]
# I used this architecture to solve it. There are many other possible solutions.

# %%
# Your code here

# Build a model using the "Sequential" API
model = keras.Sequential([
      keras.Input(shape=(2)), # One input layer with 2 input feature variables
      layers.Dense(8, activation='relu'),
      layers.Dense(8, activation='relu'),
     layers.Dense(8, activation='relu'),
      layers.Dense(8, activation='relu'),
      layers.Dense(1) # Final layer to predict the label, with 2 classes (1 or 0)
  ])


# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.02), # The Adam optimizer (an improvement over stochastic gradient descent)
    loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), # Loss function for binary classification
    metrics=['accuracy'], # Print the accuracy after each epoch
)

# %%
# Fit the model
history = model.fit(x_train, y_train, validation_split=0.1, epochs=80, batch_size=16, verbose=1)
# Out:
# Epoch 1/80
# 26/26 [==============================] - 2s 12ms/step - loss: 0.6838 - accuracy: 0.5210 - val_loss: 0.6716 - val_accuracy: 0.5111
# Epoch 2/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.6702 - accuracy: 0.5160 - val_loss: 0.6445 - val_accuracy: 0.5556
# Epoch 3/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.6685 - accuracy: 0.5457 - val_loss: 0.6647 - val_accuracy: 0.5333
# Epoch 4/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.6599 - accuracy: 0.5605 - val_loss: 0.6541 - val_accuracy: 0.5333
# Epoch 5/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.6654 - accuracy: 0.5605 - val_loss: 0.6570 - val_accuracy: 0.5778
# Epoch 6/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.6441 - accuracy: 0.5654 - val_loss: 0.6461 - val_accuracy: 0.6000
# Epoch 7/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.6349 - accuracy: 0.5901 - val_loss: 0.6156 - val_accuracy: 0.6667
# Epoch 8/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.6280 - accuracy: 0.6420 - val_loss: 0.6004 - val_accuracy: 0.6667
# Epoch 9/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.6027 - accuracy: 0.5901 - val_loss: 0.5937 - val_accuracy: 0.7778
# Epoch 10/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.5920 - accuracy: 0.6765 - val_loss: 0.6213 - val_accuracy: 0.6222
# Epoch 11/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.5161 - accuracy: 0.7630 - val_loss: 0.5361 - val_accuracy: 0.7333
# Epoch 12/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.4268 - accuracy: 0.7975 - val_loss: 0.5209 - val_accuracy: 0.7556
# Epoch 13/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.3671 - accuracy: 0.8272 - val_loss: 0.4486 - val_accuracy: 0.7556
# Epoch 14/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.3093 - accuracy: 0.8296 - val_loss: 0.3287 - val_accuracy: 0.8667
# Epoch 15/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.3105 - accuracy: 0.8395 - val_loss: 0.3496 - val_accuracy: 0.8222
# Epoch 16/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.2875 - accuracy: 0.8370 - val_loss: 0.4182 - val_accuracy: 0.7778
# Epoch 17/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.3257 - accuracy: 0.8420 - val_loss: 0.2740 - val_accuracy: 0.8444
# Epoch 18/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.2891 - accuracy: 0.8395 - val_loss: 0.2737 - val_accuracy: 0.8444
# Epoch 19/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.2698 - accuracy: 0.8642 - val_loss: 0.2641 - val_accuracy: 0.8444
# Epoch 20/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.2171 - accuracy: 0.8741 - val_loss: 0.2088 - val_accuracy: 0.8667
# Epoch 21/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.2502 - accuracy: 0.8790 - val_loss: 0.4034 - val_accuracy: 0.8222
# Epoch 22/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.2178 - accuracy: 0.8790 - val_loss: 0.2623 - val_accuracy: 0.8444
# Epoch 23/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.2229 - accuracy: 0.8889 - val_loss: 0.4000 - val_accuracy: 0.8444
# Epoch 24/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.3770 - accuracy: 0.8173 - val_loss: 0.3175 - val_accuracy: 0.8444
# Epoch 25/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.5139 - accuracy: 0.7679 - val_loss: 0.4789 - val_accuracy: 0.7556
# Epoch 26/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.2957 - accuracy: 0.8494 - val_loss: 0.4124 - val_accuracy: 0.7778
# Epoch 27/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.2414 - accuracy: 0.8716 - val_loss: 0.3564 - val_accuracy: 0.8000
# Epoch 28/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.2036 - accuracy: 0.8765 - val_loss: 0.3161 - val_accuracy: 0.8222
# Epoch 29/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1888 - accuracy: 0.8840 - val_loss: 0.3213 - val_accuracy: 0.8000
# Epoch 30/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1843 - accuracy: 0.8840 - val_loss: 0.2385 - val_accuracy: 0.8222
# Epoch 31/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1569 - accuracy: 0.8864 - val_loss: 0.2364 - val_accuracy: 0.8000
# Epoch 32/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1509 - accuracy: 0.8914 - val_loss: 0.1702 - val_accuracy: 0.8444
# Epoch 33/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1410 - accuracy: 0.8840 - val_loss: 0.1640 - val_accuracy: 0.8667
# Epoch 34/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1012 - accuracy: 0.9185 - val_loss: 0.1016 - val_accuracy: 0.8889
# Epoch 35/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1040 - accuracy: 0.9506 - val_loss: 0.1103 - val_accuracy: 0.9778
# Epoch 36/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0893 - accuracy: 0.9630 - val_loss: 0.1003 - val_accuracy: 0.9556
# Epoch 37/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.1158 - accuracy: 0.9654 - val_loss: 0.1808 - val_accuracy: 0.9556
# Epoch 38/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0992 - accuracy: 0.9605 - val_loss: 0.1347 - val_accuracy: 0.9556
# Epoch 39/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0856 - accuracy: 0.9704 - val_loss: 0.2957 - val_accuracy: 0.9556
# Epoch 40/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0877 - accuracy: 0.9704 - val_loss: 0.1752 - val_accuracy: 0.9333
# Epoch 41/80
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0585 - accuracy: 0.9753 - val_loss: 0.3021 - val_accuracy: 0.9111
# Epoch 42/80
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0585 - accuracy: 0.9852 - val_loss: 0.0550 - val_accuracy: 1.0000
# Epoch 43/80
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0362 - accuracy: 0.9877 - val_loss: 0.0470 - val_accuracy: 0.9778
# Epoch 44/80
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0401 - accuracy: 0.9852 - val_loss: 0.0360 - val_accuracy: 1.0000
# Epoch 45/80
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0384 - accuracy: 0.9852 - val_loss: 0.7524 - val_accuracy: 0.9111
# Epoch 46/80
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1546 - accuracy: 0.9333 - val_loss: 0.2328 - val_accuracy: 0.8889
# Epoch 47/80
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1587 - accuracy: 0.9383 - val_loss: 0.4067 - val_accuracy: 0.8222
# Epoch 48/80
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0699 - accuracy: 0.9753 - val_loss: 0.0480 - val_accuracy: 1.0000
# Epoch 49/80
# 26/26 [==============================] - 0s 7ms/step - loss: 0.1652 - accuracy: 0.9481 - val_loss: 0.3479 - val_accuracy: 0.8444
# Epoch 50/80
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1759 - accuracy: 0.9309 - val_loss: 0.0394 - val_accuracy: 1.0000
# Epoch 51/80
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0668 - accuracy: 0.9753 - val_loss: 0.0509 - val_accuracy: 1.0000
# Epoch 52/80
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0530 - accuracy: 0.9802 - val_loss: 0.0307 - val_accuracy: 1.0000
# Epoch 53/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0559 - accuracy: 0.9926 - val_loss: 0.0208 - val_accuracy: 1.0000
# Epoch 54/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0295 - accuracy: 0.9951 - val_loss: 0.0314 - val_accuracy: 1.0000
# Epoch 55/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0295 - accuracy: 0.9926 - val_loss: 0.0320 - val_accuracy: 1.0000
# Epoch 56/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0267 - accuracy: 0.9951 - val_loss: 0.0333 - val_accuracy: 1.0000
# Epoch 57/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0465 - accuracy: 0.9877 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 58/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9951 - val_loss: 0.0152 - val_accuracy: 1.0000
# Epoch 59/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0168 - accuracy: 0.9951 - val_loss: 0.0141 - val_accuracy: 1.0000
# Epoch 60/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0206 - accuracy: 0.9975 - val_loss: 0.0341 - val_accuracy: 1.0000
# Epoch 61/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 0.9926 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 62/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0142 - accuracy: 0.9975 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 63/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0143 - accuracy: 0.9975 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 64/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0129 - accuracy: 0.9951 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 65/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0393 - accuracy: 0.9901 - val_loss: 0.0291 - val_accuracy: 1.0000
# Epoch 66/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0640 - accuracy: 0.9852 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 67/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0269 - accuracy: 0.9901 - val_loss: 0.0369 - val_accuracy: 0.9778
# Epoch 68/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0259 - accuracy: 0.9901 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 69/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0161 - accuracy: 0.9951 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 70/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0111 - accuracy: 0.9975 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 71/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0304 - accuracy: 0.9926 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 72/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0199 - accuracy: 0.9951 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 73/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0195 - accuracy: 0.9951 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 74/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0221 - accuracy: 0.9926 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 75/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 0.9926 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 76/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 77/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 0.9951 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 78/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 0.9975 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 79/80
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0086 - accuracy: 0.9975 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 80/80
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 0.9951 - val_loss: 0.0117 - val_accuracy: 1.0000

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], 'g', label='Validation loss')
plt.xlabel('Epoch #')
plt.ylabel('Loss (Binary cross-entropy)')
plt.title('Loss')
plt.legend()

# %%
# Evaluate model on test set

score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.009079200215637684
# Test accuracy: 1.0

# %% [markdown]
# #### Question 3:
#
# For this question you will use the [Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist) dataset. As with the MNIST dataset, your task will be to classify the images in the dataset using a neural network. You may use this [tutorial](https://www.tensorflow.org/tutorials/keras/classification) as a guide, but please try as far as possible to do this on your own, using what you have learned in this notebook as a reference.

# %%
# Getting the data

fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %% [markdown]
# #### a) Visualize the images in the dataset and explore the labels.

# %%
# Plot a random sample from the dataset
indices = np.random.choice(len(train_images), size=9, replace=False)

for count, value in enumerate(indices):
    plt.subplot(3, 3, count+1)
    plt.imshow(train_images[value], cmap="gray")
    plt.title(train_labels[value])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### b) Build a neural network to classify the images. Use an appropriate loss and optimizer to compile it.

# %%
# Normalize images

train_images = train_images / 255.0
test_images = test_images / 255.0

# Build network
model = tf.keras.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compile model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %% [markdown]
# #### c) Train your model. What is the final loss of your model? What is the final accuracy? How does this accuracy compare to random guessing on this dataset?

# %%
history = model.fit(train_images, train_labels, validation_split=0.1, epochs=5)
# Out:
# Epoch 1/5
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.5009 - accuracy: 0.8235 - val_loss: 0.3886 - val_accuracy: 0.8593
# Epoch 2/5
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.3792 - accuracy: 0.8639 - val_loss: 0.3685 - val_accuracy: 0.8703
# Epoch 3/5
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.3390 - accuracy: 0.8770 - val_loss: 0.3616 - val_accuracy: 0.8627
# Epoch 4/5
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.3150 - accuracy: 0.8857 - val_loss: 0.3476 - val_accuracy: 0.8723
# Epoch 5/5
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.2966 - accuracy: 0.8908 - val_loss: 0.3219 - val_accuracy: 0.8830

# %% [markdown]
# #### d) Evaluate your model on the test dataset. Visualize the loss curve.

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], 'g', label='Validation loss')
plt.xlabel('Epoch #')
plt.ylabel('Loss (Categorical cross-entropy)')
plt.title('Loss')
plt.legend()

# %%
# Evaluate model on test set

score = model.evaluate(test_images, test_labels, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.3436787724494934
# Test accuracy: 0.8794999718666077
